# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import time
import numpy as np
from graph import random_connected_graph
from optimizers import BruteForceOptimizer
from IPython.display import clear_output

# %%
g = random_connected_graph(7)
g.show(vshift=-1.2)

# %%
solver = BruteForceOptimizer(g)
solution = solver.solve()

# %%
iterations = []
distances = []
for it, sol in enumerate(solver.recording):
    iterations.append(it)
    distances.append(sol.length)
    print([it, sol, sol.length])
    clear_output(wait=True)
# Out:
# [5039, 1 -> 0 -> 5 -> 6 -> 4 -> 2 -> 3 -> 1, 217]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(iterations, distances)
plt.xlabel('Iteration')
plt.ylabel('Distance')
plt.show()
