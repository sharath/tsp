# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import numpy as np
from graph import UndirectedWeightedGraph as uwg

# %%
np.random.seed(20)
g = uwg()
for i in range(9):
    g.add_vertex(str(i))
g.add_edge('0', '5')

# %%
g.show(vshift=-1)
