# %%
from IPython.display import clear_output
from generate import simulated_annleaing
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style("white")

# %%
plt.rcParams["figure.figsize"] = (6,6)

# %%
iterations, paths, bf, temps, prob = simulated_annleaing(T=50, points=5, dim=10, T_bound=0.002, T_decay=0.999, max_iter=10000, T_schedule='exp', seed=0)

# %%
plt.scatter(*paths[0], color='black', zorder=1000)
plt.plot(*paths[1], color='black', zorder=50)
plt.xticks([])
plt.yticks([])
plt.box(False)
plt.savefig('xc.png')

# %%
plt.scatter(*paths[0], color='black', zorder=1000)
plt.plot(*paths[1], color='black', zorder=50)
plt.plot(*paths[0], color='gray', zorder=1, linestyle='dotted')
plt.xticks([])
plt.yticks([])
plt.box(False)
plt.savefig('permute.png')

# %%
plt.scatter(*paths[1], color='black', zorder=1000)
plt.plot([6.027633760716439,
  7.151893663724195],
 [8.917730007820797,
  4.375872112626925], color='black', zorder=50)
plt.plot([5.448831829968968,
  4.236547993389047,
  5.4881350392732475],
 [9.636627605010293,
  3.8344151882577773,
  6.458941130666561], color='black', zorder=50)
plt.plot(*paths[0], color='gray', zorder=1)
plt.xticks([])
plt.yticks([])
plt.box(False)
plt.savefig('xp.png')
